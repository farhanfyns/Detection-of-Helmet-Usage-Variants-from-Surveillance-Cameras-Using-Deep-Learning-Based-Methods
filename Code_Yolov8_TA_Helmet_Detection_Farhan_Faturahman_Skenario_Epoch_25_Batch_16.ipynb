# %% [markdown]
# # **EPOCH 25 BATCH 16**

# %%
from ultralytics import YOLO
import os

# Path utama proyek
base_path = r"C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman"

# Path ke dataset (data.yaml)
data_yaml_path = os.path.join(base_path, "Dataset", "data.yaml")

# Path untuk menyimpan hasil training
save_dir = os.path.join(base_path, "Yolov8", "Hasil Pengujian Epoch", "Epoch 25", "Batch 16")
os.makedirs(save_dir, exist_ok=True)

# Inisialisasi model YOLOv8n (Nano)
model = YOLO("yolov8n.pt")

# Melatih model dengan dataset helm
model.train(
    data=data_yaml_path,
    epochs=25,
    imgsz=640,
    batch=16,
    lr0=0.01,
    optimizer="AdamW",
    weight_decay=0.0005,
    save_dir=save_dir
)

print(f"Model dan hasil pelatihan disimpan di: {save_dir}")
# Out:
# New https://pypi.org/project/ultralytics/8.3.64 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.55  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Dataset\data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=C:\Users\fatur\runs\detect\train2
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 225 layers, 3,011,628 parameters, 3,011,612 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir C:\Users\fatur\runs\detect\train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Scanning C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Dataset\train\labels.cache..
# val: Scanning C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Dataset\valid\labels.cache...
# Plotting labels to C:\Users\fatur\runs\detect\train2\labels.jpg...
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\fatur\runs\detect\train2
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      2.15G      1.477       2.87      1.222         43        640: 100%|██████████| 49/49 [00:08<00:00,  5.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306    0.00602      0.116    0.00374    0.00119
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      2.14G      1.363      1.713      1.241         39        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306     0.0054       0.15     0.0145    0.00588
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      2.18G      1.325      1.593      1.244         33        640: 100%|██████████| 49/49 [00:06<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.197      0.344      0.216      0.119
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      2.16G      1.222      1.425        1.2         41        640: 100%|██████████| 49/49 [00:06<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.325      0.554      0.261      0.162
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      2.14G      1.204      1.327      1.175         37        640: 100%|██████████| 49/49 [00:06<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.393      0.608      0.469      0.295
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      2.15G      1.158      1.327      1.161         32        640: 100%|██████████| 49/49 [00:06<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<0
#                    all        168        306      0.673        0.5      0.543      0.366
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      2.14G      1.156      1.285      1.124         24        640: 100%|██████████| 49/49 [00:06<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<0
#                    all        168        306      0.478      0.648      0.583      0.347
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      2.15G      1.115      1.215      1.128         26        640: 100%|██████████| 49/49 [00:06<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.451      0.793      0.608      0.432
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      2.16G       1.09      1.194       1.08         37        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<0
#                    all        168        306      0.522      0.753      0.609      0.421
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      2.14G      1.057      1.129      1.091         44        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.611       0.62      0.655      0.463
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      2.16G      1.092      1.127      1.068         44        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.633      0.681      0.692      0.489
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      2.15G      1.007      1.079      1.074         34        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.716      0.562      0.594      0.449
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      2.15G      1.019      1.036      1.065         46        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.624      0.641      0.681      0.502
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      2.16G      1.007     0.9918      1.047         39        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.638      0.707      0.761      0.557
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      2.16G     0.9968     0.9699      1.048         37        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.654      0.751      0.761      0.558
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      2.14G     0.9437     0.9385      1.063         25        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306       0.67      0.697       0.76      0.567
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      2.14G     0.9191      0.856      1.044         24        640: 100%|██████████| 49/49 [00:07<00:00,  7.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:00<0
#                    all        168        306      0.726      0.845      0.853       0.66
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      2.14G      0.894     0.8255      1.028         24        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.843      0.716      0.822      0.638
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      2.14G     0.8961     0.8199      1.031         34        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.784      0.846      0.874      0.676
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      2.14G     0.8618     0.7456      1.014         20        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.799      0.801       0.88      0.686
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      2.14G      0.838      0.728     0.9992         27        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.851      0.792      0.893      0.697
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      2.14G     0.8172     0.6909     0.9963         24        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.861      0.824      0.903      0.691
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      2.14G     0.7915      0.676     0.9827         26        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.852      0.872      0.905      0.707
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      2.14G     0.7849     0.6491     0.9808         30        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.821      0.861      0.914      0.712
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      2.14G     0.7761     0.6228     0.9652         23        640: 100%|██████████| 49/49 [00:07<00:00,  6.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306      0.871      0.852      0.925      0.732
# 25 epochs completed in 0.070 hours.
# Optimizer stripped from C:\Users\fatur\runs\detect\train2\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\fatur\runs\detect\train2\weights\best.pt, 6.2MB
#
# Validating C:\Users\fatur\runs\detect\train2\weights\best.pt...
# Ultralytics 8.3.55  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 6/6 [00:01<0
#                    all        168        306       0.87      0.852      0.925      0.733
#        helmet_fullface         27         27       0.88      0.778      0.897      0.707
#        helmet_halfface         88        105      0.825      0.905       0.94      0.775
#     helmet_nonstandard         48         52      0.777      0.827       0.87      0.688
#              no_helmet         75        122          1      0.898      0.993      0.764
# Speed: 0.2ms preprocess, 2.2ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to C:\Users\fatur\runs\detect\train2
# Model dan hasil pelatihan disimpan di: C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Yolov8\Hasil Pengujian Epoch\Epoch 25\Batch 16

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
import pandas as pd

# Path ke model terbaik hasil training
model_path = r"C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Yolov8\Hasil Pengujian Epoch\Epoch 25\Batch 16\train\weights\best.pt"

# Path ke dataset (data.yaml)
data_yaml_path = r"C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Dataset\data.yaml"

# Path penyimpanan hasil pengujian
test_save_dir = os.path.join(os.path.dirname(save_dir))
os.makedirs(test_save_dir, exist_ok=True)

# Load model
model = YOLO(model_path)

# Evaluasi model pada dataset testing
metrics = model.val(data=data_yaml_path, split='test', save_dir=test_save_dir)
# Out:
# Ultralytics 8.3.55  Python-3.10.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\fatur\Documents\Source Code TA_Helmet Detection_Farhan Faturahman\Dataset\test\labels.cache... 1
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:01
#                    all        167        303      0.868      0.848      0.935      0.729
#        helmet_fullface         24         24      0.796      0.958      0.961      0.709
#        helmet_halfface         84        103      0.872      0.806      0.932      0.759
#     helmet_nonstandard         52         57      0.854      0.823      0.912      0.723
#              no_helmet         72        119       0.95      0.805      0.937      0.726
# Speed: 0.2ms preprocess, 3.3ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to C:\Users\fatur\runs\detect\val

# %%
# Path folder hasil testing
base_path = os.path.join(test_save_dir, "Batch 16", "val")

# Path file evaluasi
confusion_matrix_path = os.path.join(base_path, "confusion_matrix.png")
confusion_matrix_normalized_path = os.path.join(base_path, "confusion_matrix_normalized.png")
f1_curve_path = os.path.join(base_path, "F1_curve.png")

# Menampilkan Confusion Matrix
print("Confusion Matrix (Testing):")
display(Image(filename=confusion_matrix_path, width=600, height=600))

# Menampilkan Confusion Matrix Normalized
print("Confusion Matrix Normalized (Testing):")
display(Image(filename=confusion_matrix_normalized_path, width=600, height=600))

# Menampilkan F1 Confidence Curve
print("F1 Confidence Curve (Testing):")
display(Image(filename=f1_curve_path, width=800, height=400))

# Membaca hasil evaluasi dari CSV
results_csv_path = os.path.join(save_dir, "train", "results.csv")
results_df = pd.read_csv(results_csv_path)

print("\nTraining Results (CSV):")
pd.set_option('display.max_rows', None)  # Menampilkan semua baris
pd.set_option('display.max_columns', None)  # Menampilkan semua kolom
display(results_df)
# Out:
# Confusion Matrix (Testing):
# Confusion Matrix Normalized (Testing):
# F1 Confidence Curve (Testing):
# Training Results (CSV):
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   13.8391         1.47671         2.87012         1.22218
# 1       2   23.4863         1.36292         1.71251         1.24095
# 2       3   32.4928         1.32461         1.59300         1.24357
# 3       4   40.9220         1.22187         1.42492         1.20018
# 4       5   49.3160         1.20423         1.32726         1.17537
# 5       6   57.7063         1.15788         1.32700         1.16132
# 6       7   66.1153         1.15608         1.28536         1.12402
# 7       8   74.5862         1.11470         1.21539         1.12833
# 8       9   83.2416         1.09001         1.19367         1.08028
# 9      10   91.7739         1.05721         1.12921         1.09116
# 10     11  100.5740         1.09248         1.12664         1.06831
# 11     12  109.3440         1.00658         1.07875         1.07402
# 12     13  118.0910         1.01925         1.03617         1.06528
# 13     14  126.9400         1.00711         0.99179         1.04744
# 14     15  135.7650         0.99684         0.96988         1.04833
# 15     16  173.4290         0.94367         0.93850         1.06285
# 16     17  182.2390         0.91913         0.85603         1.04401
# 17     18  190.8030         0.89405         0.82550         1.02762
# 18     19  199.3680         0.89608         0.81993         1.03086
# 19     20  208.0950         0.86185         0.74564         1.01396
# 20     21  216.8680         0.83803         0.72800         0.99916
# 21     22  225.6290         0.81725         0.69091         0.99628
# 22     23  234.4340         0.79152         0.67603         0.98274
# 23     24  243.2630         0.78493         0.64907         0.98081
# 24     25  252.0680         0.77607         0.62279         0.96521
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.00602            0.11580           0.00374
# 1                0.00540            0.14963           0.01453
# 2                0.19724            0.34393           0.21647
# 3                0.32514            0.55430           0.26079
# 4                0.39343            0.60768           0.46852
# 5                0.67297            0.49989           0.54324
# 6                0.47780            0.64782           0.58315
# 7                0.45125            0.79260           0.60827
# 8                0.52151            0.75253           0.60923
# 9                0.61148            0.61981           0.65472
# 10               0.63291            0.68136           0.69177
# 11               0.71584            0.56235           0.59431
# 12               0.62434            0.64129           0.68062
# 13               0.63775            0.70693           0.76079
# 14               0.65357            0.75059           0.76147
# 15               0.66951            0.69715           0.75960
# 16               0.72601            0.84483           0.85275
# 17               0.84321            0.71632           0.82188
# 18               0.78391            0.84580           0.87358
# 19               0.79865            0.80115           0.87999
# 20               0.85141            0.79164           0.89254
# 21               0.86121            0.82385           0.90315
# 22               0.85192            0.87151           0.90510
# 23               0.82051            0.86060           0.91368
# 24               0.87078            0.85178           0.92496
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0               0.00119       2.16496           inf       3.32719  0.070612
# 1               0.00588       1.75961           inf       1.77503  0.040351
# 2               0.11877       1.56312       2.89276       1.47562  0.009826
# 3               0.16173       1.24646       5.56245       1.36918  0.008812
# 4               0.29519       1.27288       1.62529       1.30827  0.008416
# 5               0.36598       1.12509       1.50177       1.24792  0.008020
# 6               0.34736       1.36344       1.49762       1.34834  0.007624
# 7               0.43200       1.05980       1.23410       1.15538  0.007228
# 8               0.42141       1.04921       1.10302       1.17357  0.006832
# 9               0.46261       0.99392       1.04113       1.11731  0.006436
# 10              0.48910       0.99916       1.17757       1.13137  0.006040
# 11              0.44898       0.92892       1.36829       1.11218  0.005644
# 12              0.50245       0.96503       1.09704       1.13027  0.005248
# 13              0.55680       0.99946       0.92696       1.09618  0.004852
# 14              0.55819       0.93005       0.91664       1.08273  0.004456
# 15              0.56748       0.92813       0.89929       1.10329  0.004060
# 16              0.65982       0.86108       0.82302       1.05338  0.003664
# 17              0.63773       0.86573       0.80252       1.03868  0.003268
# 18              0.67588       0.86405       0.72334       1.05889  0.002872
# 19              0.68584       0.83504       0.68873       1.04810  0.002476
# 20              0.69730       0.84300       0.70327       1.03348  0.002080
# 21              0.69080       0.88038       0.64933       1.06278  0.001684
# 22              0.70716       0.82547       0.65039       1.02580  0.001288
# 23              0.71162       0.83914       0.62803       1.02215  0.000892
# 24              0.73244       0.80636       0.61108       1.00491  0.000496
#
#       lr/pg1    lr/pg2
# 0   0.003265  0.003265
# 1   0.006337  0.006337
# 2   0.009145  0.009145
# 3   0.008812  0.008812
# 4   0.008416  0.008416
# 5   0.008020  0.008020
# 6   0.007624  0.007624
# 7   0.007228  0.007228
# 8   0.006832  0.006832
# 9   0.006436  0.006436
# 10  0.006040  0.006040
# 11  0.005644  0.005644
# 12  0.005248  0.005248
# 13  0.004852  0.004852
# 14  0.004456  0.004456
# 15  0.004060  0.004060
# 16  0.003664  0.003664
# 17  0.003268  0.003268
# 18  0.002872  0.002872
# 19  0.002476  0.002476
# 20  0.002080  0.002080
# 21  0.001684  0.001684
# 22  0.001288  0.001288
# 23  0.000892  0.000892
# 24  0.000496  0.000496
